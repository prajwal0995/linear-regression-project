# %% [raw]
# 1. What is Machine Learning and why its used for?
#    Machine Learning is branch of Artifical Intelligence that allows computers to learn from data and make decisions without being explicitly programmed
# Machine Learning is used to solve problems where:
# A.Manual rules are impossible or very hard
# Example : Detecting spam emails
#           Facial recognition
#           predicting stock prices
#
# B.ML can learn from experience
# Example : More data
#           Better training
#           More features
#
# C.ML can handle large, complex data
# Example : Linear Regression - Predicts house prices
#
# D.Automation & efficiency
# ML automates taskes, reduces human efforts, and increases accuracy.
# Example : Chatbots
#           Recommendation systems
#           Manufacturing robots

# %% [raw]
# 2. Define what is function. explain why a function is called a basic block of ML?
#    A function ia a relationship between input(s) and output(s) where:
# Each input gives exactly one output.
# f(x) = y
# x - input
# f - function
# y - output
#
# Example: f(x)=2x+3
# if you give x=5, the output is:
#                                f(5)=2(5)+3=13
#
# Why Function is called the basic block of machine learning?
#   - Because every Machine Learning model is fundamentally a function.
#   - ML takes input and return output - just like a math function
#
# A.ML models map input- output
#    every ML model does this:
#                          model:X-Y
# Examples:
#   - Linear Regression:
#                     f(x)=mx+c
#   -Logistic Regression
#                     f(x)=σ(wx+b)
#   -Neural Network
#                 f(x)=σ(Wx+b)
#
# B.Learning = finding the best function
# machine learning uses algorithms to learn the parameters(weights, bias) of a function.
# Example:
#   - Linear Regression
#     m (slope)
#     c(intercept)
#   - Neural Networks
#     W(weights)
#     b(bias)
#
# C. All predictions are function outputs
#    - Predicting house price
#    - Predicting if email is spam
#    - Predicting stock value
#    - Classifing an image
#
# D.Activation Function power deep learning
#    - Sigmoid
#    - Relu
#    - Tanh

# %% [raw]
# 3. Explain in own words what is supervised, unsupervised, and semi-supervised ML?
# A. Supervised Learning
#    Supervised learning is a type of ML where the model learns from labeled data meaning the input already has a known correct output.
# HOW ITS WORKS:
#     You give the algorithm:
#     input(x)
#     output(y)
# Example:
#    a.Give 1000 images labeled as cat or dog- model learns to classify.
#    b.House data + price- model predicts price
#
# B. Unsupervised Learning
#    Unsupervised learning works on unlabeled data-meaning only input is given, but there are no correct answers
# HOW ITS WORKS:
#    The model tries to find patterns,group, or structures on its own.
# EXAMPLE:
#    a.Grouping customers based on behavior
#    b.Clustering similar products on Amazon
#    c.Finding
#
# C.Semisupervised Learning
#    Semi supervised learning uses a mix of labled and unlabled data
#    A small amount of labeled data + large amount of unlabled data
# HOW ITS WORKS:
#    Labeling data is expensive or difficult
#    Unlabeled data is easy to get
# EXAMPLE:
#    a.Only 1000 images are labeled as "cat/dog", but thousands are unlabeled
#    b.Speech recognition (some audio labeled, most unlabeled)

# %% [raw]
#  4. What is feature scaling? Why is it important?
#     Feature scaling is process of transforming all the numerical features(columns) in dataset to be on a similar scale
# - Why is Feature Scaling important?
#     Because ML algorithms perform better when all features are in the same scale.
#
# A. Prevents one feature from dominating others
# EXAMPLE:
#         Feature                 Range
#         Age                     18-60
#         Salary                  20,000-200,000
#
#    Salary has huge numbers.
#    If you dont scale, the model will think salary is more important, which is wrong.
#
# B. Makes gradient descent work faster
#    Models like:
#    a.Linear Regression
#    b.Logistic Regression
#    c.Neural Networks
#
# C. Distance based models need equal scale
#    Algorithm like:
#    a.KNN (K-Nearest Neighbors)
#    b.K-Means clustering
#    c.PCA(Dimensionality Reduction)
#
# D. Improves accuracy
#   Many models will give low accuracy or wrong clusters without scaling
#   Scaling helps the models understand true patterns in data

# %% [raw]
# 5. Explain what Normalization and Standardization are. Tabulate their differences and their use cases
# A. Normalization
#    Normalization (also called min-max scalling) transforms the data to a find range usually 0 to 1
# WHEN TO USE -
#     Normalization (min-max scaling)
#     use when data does not follow normal distribution,and when all features must lie in a specific range.
# BEST FOR:
#     a.KNN(K-Nearest Neighbors)
#     b.K-Means Clustering
#     c.Neural Networks
#     d.Algorithms involving distance calculation(because distance change with scale)
#
# B. Standardization
#    Standardization(also called Z-score Scaling) transforms the data so it has:
#    a.Mean=0
#    b.Standard deviation=1
# WHEN TO USE -
#    Standardization (Z-score scalling)
#    use when data follows a Gaussion Distribution or near normal distribution.
# BEST FOR:
#    a.Linear Regression
#    b.Logistic Regression
#    c.SVM
#    d.Neural Networks

# %% [raw]
# 6. Define what is Linear Regression. Why is Linear Regression important?
#    Linear Regression is a supervised machine learning algorithm used to predict a continuous numerical value based on the relationship between input variable and output
# WHERE:
#     a.Y= predicted output
#     b.X= input
#     c.m= slope (how much y changes when x change)
#     d.c= intercept (value of y when x =0)
# Why Linear Regression important ?
#    Linear Regression is extremely important in machine learning and statistics for several reasons:
#    a.It is simple and easy to understand
#    b.It helps in prediction
#    c.Its shows relationships between variables
#    d.It is the foundation of many ML models
#    e.Works well for real world problems

# %% [raw]
# 7. What is goal of the best fit line?
#   The goal of the best-fit line in Linear Regression is:
#   To draw a line that best represent the relationship between the intput(X) and output(Y) by minimizing the error between predicted values and actual values.
#   This line should be as close as possible to all data points.
#
# Why it is important?
#    Because a good best fit line:
#    a.Shows the relationship between variables clearly
#    b.Gives accurate predictions
#    c.Reduces error
#    d.Helps understand trends

# %% [raw]
# 8. Explain the metric used to determine the effectiveness of Linear Regression
# model.
#    Linear Regression is evaluated using error-based metrics and a goodness-of-fit metric
#    These metrics tell how well the model predicts the target values.
#    a.Mean Squared Error(MSE)
#    b.Root Mean Squared Error(RMSE)
#    c.Mean Absolute Error(MAE)
